# %%
# !pip install streamlit -q

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 35.203.170.6

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# [..................] / rollbackFailedOptional: verb npm-session 277836514b08993
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.203.170.6:8501
#
# npx: installed 22 in 2.568s
# your url is: https://pretty-clouds-fry.loca.lt
# 2023-09-09 19:57:53.405683: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-09 19:57:54.523486: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
